# %%
! pip install scikit-learn-extra
# Out:
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 31.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.10/site-packages (from scikit-learn-extra) (1.23.5)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn-extra) (1.11.2)
# Requirement already satisfied: scikit-learn>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn-extra) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.1.0)
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0

# %%
! pip install rstl
# Out:
# Collecting rstl
#   Downloading rstl-0.1.3-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rstl) (1.23.5)
# Installing collected packages: rstl
# Successfully installed rstl-0.1.3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids
from sklearn.cluster import SpectralClustering
# %tensorflow_version 1.x
import tensorflow as tf
import keras
import keras.backend as K
from keras import layers
from keras.models import Sequential,Model
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import time
print(tf.__version__)
from keras.layers import MultiHeadAttention
from keras.layers import Dense
import gc
from keras.layers import concatenate
import csv
import math
import warnings
import os

# import xgboost as xgb
warnings.filterwarnings('ignore')
# import GPy, GPyOpt
tfkl = tf.keras.layers
tfk = tf.keras

from rstl import STL
from texttable import Texttable
# Out:
# 2.12.0

# %%
rd='Mahdian/'

def get_dataset_params(dataset_name = 'cif-12'):
    suilin_smape = False

    
    #-------------------------------------------------- NN5 ------------------------------------------------#
    if dataset_name == 'nn5':
        dataset_path = '/kaggle/working'+'/' + 'NN5'
        raw_data = pd.read_csv('/kaggle/input/dataset-nn5-fixing/nn5.csv',sep='delimeter',header=None)

        features = pd.read_csv("/kaggle/input/ae-nn5-unsupervised-ae/Features_nn5_LSTM_32.csv",sep=',', header=None)


        lag = 150
        look_forward = 56
        batch_size = 1
        epochs = 1
        learning_rate = 0.0001
        suilin_smape = False
        frequency =7

    #------------------------------------------------------------------------------------------------------------#

    sample_overlap = look_forward - 1


    raw_data = raw_data[0].str.split(',', expand=True)

    raw_data = raw_data.to_numpy().astype('float64')
    features = features.to_numpy().astype('float64')
    dataset = []
    for i in range(len(raw_data)):
        dataset.append(raw_data[i][~np.isnan(raw_data[i])])


    return dataset, features, lag, look_forward, sample_overlap, learning_rate, dataset_path, suilin_smape, frequency

# %%
def normalize_dataset(dataset, look_forward ):
    data_means = [];
    for index in range(len(dataset)):
    # Mean Noramlization
        series_mean = np.mean(dataset[index][:len(dataset[index]) - look_forward]) # Train Mean: look_forward || Full Mean: Mean: look_forward = 0

        if series_mean == 0:
            series_mean = 0.001

        data_means.append(series_mean)
        dataset[index] = np.divide(dataset[index], series_mean)

        # Log Transformation
        dataset[index] = np.log(dataset[index] + 1)

    return dataset, np.array(data_means)

def rescale_data_to_main_value(data, means, dataset_seasonal = []):

    for index in range(len(data)):
        if len(dataset_seasonal) != 0:
            data[index] = data[index] + dataset_seasonal[index]
        # Revert Log Transformation
        data[index] = np.e ** data[index]
        data[index] = data[index] - 1

        # Revert Mean Normalization
        data[index] = means[index] * data[index]




    return data

def normalize_feature_vectors(features):
    #------------------- Z-score ----------------------#
#     means = features.mean(0)
#     stds = features.std(0)

#     for i in range(len(features)):
#         features[i] = (features[i] - means) / stds

    #--------------------Min - Max---------------------#
    minimum = features.min(0)
    maximum = features.max(0)

    for i in range(len(features)):
        features[i] = (features[i] - minimum) / (maximum - minimum)


    return features

"""![root_mean_square_deviation.svg](attachment:root_mean_square_deviation.svg)"""

#RMSE
def root_mean_squared_error(actual, forecast, method = 'single_value'):
    # Methods = single_value | per_series
    if method == 'single_value':
        #Flatten To One Vector
        actual = actual.flatten()
        forecast = forecast.flatten()

        return np.sqrt(np.mean(np.square(actual - forecast)))
    elif method == 'per_series':
        rmses = []
        for i in range(len(actual)):
            rmses.append(np.sqrt(np.mean(np.square(actual[i] - forecast[i]))))

        return rmses

"""![YIy33.png](attachment:YIy33.png)"""

#SMAPE
def single_point_smape(actual, forecast, suilin_smape = False):
    if suilin_smape == True:
        epsilon = 0.1

        return (np.sum(2 * np.abs(forecast - actual) / max((np.abs(actual) + np.abs(forecast))+ epsilon, 0.5 + epsilon)))
    else:
        return (np.sum(2 * np.abs(forecast - actual) / (np.abs(actual) + np.abs(forecast))))

def smape(actual, forecast, method = 'single_value', suilin_smape = False):
    # Methods = single_value | per_series
    if method == 'single_value':
        #Flatten To One Vector
        actual = actual.flatten()
        forecast = forecast.flatten()
        sum_smape = 0
        for i in range(len(actual)):
            sum_smape += single_point_smape(actual[i], forecast[i], suilin_smape)
        return 100 * sum_smape / len(actual)

    elif method == 'per_series':
        smapes = []
        for i in range(len(actual)):
            sum_smape = 0
            for j in range(len(actual[i])):
                sum_smape += single_point_smape(actual[i,j], forecast[i,j], suilin_smape)
            smapes.append(100 * sum_smape / len(actual[i]))
        return np.array(smapes)

# Create Samples from DataSet
def create_dataset(sample, look_back, look_forward, sample_overlap, dataset_seasonal):
    if(sample_overlap >= look_forward or sample_overlap < 0): sample_overlap = look_forward - 1
    if(look_forward == 1): sample_overlap = 0

    dataX, dataY, dataY_seasonal = [], [], []
    dataX_means, dataY_means = [], []
    for i in range(0, len(sample) - look_back - look_forward+1, look_forward - sample_overlap):
        dataX.append(sample[i:(i+look_back), 0])
        dataY.append(sample[(i + look_back):(i + look_back + look_forward), 0])

        dataY_seasonal.append(dataset_seasonal[(i + look_back):(i + look_back + look_forward)])


    return np.array(dataX), np.array(dataY), np.array(dataY_seasonal)

# %%
testsize = 20/100
valsize = 20/100

def create_sample(dataX, dataY, data_mean, dataY_seasonal):
    test_size=1
    val_size=1

    train_size=(len(dataX)-test_size)

    trainX, testX = dataX[0:train_size,:], dataX[train_size:,:]
    trainY, testY = dataY[0:train_size,:], dataY[train_size:,:]

    valX, valY = trainX[train_size-val_size:train_size,:],trainY[train_size-val_size:train_size, :]

    trainX = np.reshape(trainX, (trainX.shape[0],1, trainX.shape[1]))
    valX = np.reshape(valX, (valX.shape[0],1, valX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0],1, testX.shape[1]))

    val_means = np.full(len(valY), data_mean)
    test_means = np.full(len(testY), data_mean)

    val_seasonal = dataY_seasonal[train_size-val_size:train_size, :]
    test_seasonal = dataY_seasonal[train_size:,:]

    return np.array(trainX),np.array(valX),np.array(testX),np.array(trainY),np.array(valY),np.array(testY), test_means, val_means, val_seasonal, test_seasonal

# Preprocess Data For Sampling
def all_pre_process(all_dataset, lag, look_forward, sample_overlap, data_means, dataset_seasonal):
    look_back = lag

    trainX = []
    trainY = []

    valX = []
    valY = []

    testX = []
    testY = []

    all_test_means = []
    all_val_means = []

    all_test_seasonals = []
    all_val_seasonals = []

    for index in range(len(all_dataset)):
        sample = np.array(all_dataset[index])
        sample = sample.reshape(sample.shape[0], 1)

        dataX_s, dataY_s, dataY_seasonal = create_dataset(sample, look_back, look_forward, sample_overlap, dataset_seasonal[index])

        temp_trainX, temp_valX, temp_testX, temp_trainY, temp_valY, temp_testY, test_means, val_means, val_seasonal, test_seasonal = create_sample(dataX_s,dataY_s,data_means[index], dataY_seasonal)

        trainX = trainX + temp_trainX.tolist()
        trainY = trainY + temp_trainY.tolist()

        valX = valX + temp_valX.tolist()
        valY = valY + temp_valY.tolist()

        testX = testX + temp_testX.tolist()
        testY = testY + temp_testY.tolist()

        all_test_means = all_test_means + test_means.tolist()
        all_val_means = all_val_means + val_means.tolist()

        all_test_seasonals = all_test_seasonals + test_seasonal.tolist()
        all_val_seasonals = all_val_seasonals + val_seasonal.tolist()


    return np.array(trainX), np.array(valX), np.array(testX), np.array(trainY), np.array(valY), np.array(testY), np.array(all_test_means), np.array(all_val_means), np.array(all_val_seasonals), np.array(all_test_seasonals)

def save_prediction_result(data, dataset_name = 'cif-6', dataset_path = ''):
    if dataset_name == '':
        filename = dataset_name + '-results.csv'
    else:
        filename = dataset_path + '/' + dataset_name + '-results.csv'


    df = pd.DataFrame(data)
    df.to_csv(filename, sep=',',index=False,header=False)

# %%
# Main Work & Functionality
def run_model_test(dataset, data_means, dataset_seasonal, dataset_name, cluster_lable, lag, look_forward, sample_overlap, batch_size, epochs, learning_rate, suilin_smape, dataset_path, use_saved_model = False, save_trained_model = False):

    # Initialize Look Forward & Back
    look_back=lag
    calculations_method = 'per_series' # single_value | per_series

    trainX, valX, testX, trainY, valY, testY, test_means, val_means, val_seasonal, test_seasonal = all_pre_process(dataset, lag, look_forward, sample_overlap, data_means, dataset_seasonal)

    # Get Model From Local Saved File
    if use_saved_model == True:
        if os.path.exists(dataset_path + '/' + dataset_name + '-model-cluster-' + str(cluster_lable)) == True:
            model = keras.models.load_model(dataset_path + '/' + dataset_name  + '-model-cluster-' + str(cluster_lable))

            val_prediction_results = model.predict([valX],batch_size=16, verbose=0)

            val_RMSE = root_mean_squared_error(valY, val_prediction_results, calculations_method)
            val_SMAPE = smape(valY, val_prediction_results, calculations_method, suilin_smape)

            ######################################################
            test_prediction_results = model.predict([testX],batch_size=16, verbose=0)

            test_RMSE = root_mean_squared_error(testY, test_prediction_results, calculations_method)
            test_SMAPE = smape(testY, test_prediction_results, calculations_method, suilin_smape)

        else:
            use_saved_model = False
            save_trained_model = True

    # Train Model From Scratch
    if use_saved_model == False:

        dense_neuron = 100
        denselayer_activation = 'linear' #None
        output_activation = 'linear' #'linear'

        print("---------------------------------------------------------------------")
        print("lag", lag)
        print("look_forward", look_forward)
        print("sample overlap", sample_overlap)
        print("trainshape", trainX.shape)
        print("valshape", valX.shape)
        print("testshape", testX.shape)
        print(learning_rate, dense_neuron, denselayer_activation, output_activation)



        validation_loss=[]
        test_loss=[]
        iter = 1
        for j in range(iter):
### Network Structure
            # #---------------------------------------Input Layer------------------------------------------#
            input_layer = layers.Input(shape = (1, lag,), name = "Input-Layer")


            lstm1=keras.layers.LSTM(128,activation='linear',return_sequences=True)(input_layer)
            lstm2=keras.layers.LSTM(64,activation='linear',return_sequences=True)(lstm1)
            conv = keras.layers.Conv1D(64,
                                          strides=2,
                                          kernel_size=4,
                                          activation=None,
                                          padding="same",)(lstm2)

            # flatten_layer1 = keras.layers.Flatten(name="Flatten-Layer")(multi_head_attention_layer)

            flatten_layer2=keras.layers.Flatten(name="Flatten-Layer2")(conv)
            # concat=keras.layers.concatenate([flatten_layer1,flatten_layer2])

            dense_layer1 = Dense(
                dense_neuron,
                activation = denselayer_activation,
                name = "Fully-Connected-Layer")(flatten_layer2)

            dense_layer2 = Dense(
                look_forward,
                activation = None,
                name = "Output-Layer")(dense_layer1)


            # Create Model
            model = Model(inputs = [input_layer], outputs = dense_layer2)

            # Optimizer
            opt=tf.keras.optimizers.Adam(learning_rate=learning_rate)

            # Compile Model
            model.compile(loss="mse",optimizer=opt,metrics=["mse"])

            for k in range(epochs):
                history = model.fit([trainX], trainY, validation_data=([valX, valY]),
                    verbose = 0,
                    batch_size = batch_size,
        #             callbacks = [
        #                 tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
        #                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=20, factor=0.5, min_lr=1e-5)
        #             ]
            ).history

                val_prediction_results = model.predict([valX],batch_size=16, verbose=0)

                val_RMSE = root_mean_squared_error(valY, val_prediction_results, calculations_method)
                val_SMAPE = smape(valY, val_prediction_results, calculations_method, suilin_smape)

                ######################################################
                test_prediction_results = model.predict([testX],batch_size=16, verbose=0)

                test_RMSE = root_mean_squared_error(testY, test_prediction_results, calculations_method)
                test_SMAPE = smape(testY, test_prediction_results, calculations_method, suilin_smape)

                validation_loss.append(np.mean(val_RMSE))
                test_loss.append(np.mean(test_RMSE))

            K.clear_session()
            gc.collect()

            # Save model to a file if wanted
            if save_trained_model == True:
                model.save(dataset_path + '/' + dataset_name + '-model-cluster-' + str(cluster_lable))

            model=None
            del history

    #############################################
    rescaled_valY = rescale_data_to_main_value(valY, val_means, val_seasonal)
    rescaled_val_prediction_results = rescale_data_to_main_value(val_prediction_results, val_means)
    val_SMAPE = smape(rescaled_valY, rescaled_val_prediction_results, calculations_method, suilin_smape)
    val_RMSE = root_mean_squared_error(rescaled_valY, rescaled_val_prediction_results, calculations_method)


    rescaled_testY = rescale_data_to_main_value(testY, test_means, test_seasonal)
    rescaled_test_prediction_results = rescale_data_to_main_value(test_prediction_results, test_means, test_seasonal)
    test_SMAPE = smape(rescaled_testY, rescaled_test_prediction_results, calculations_method)
    test_RMSE = root_mean_squared_error(rescaled_testY, rescaled_test_prediction_results, calculations_method)

    results = {
            'val_SMAPE': val_SMAPE,
            'val_RMSE': val_RMSE,
            'test_SMAPE': test_SMAPE,
            'test_RMSE': test_RMSE
        }
    #############################################

    return results

# %%
from sklearn.metrics import silhouette_score

def cluster_series(features, number_of_clusters=2):
    clustered = KMedoids(n_clusters=number_of_clusters, init='k-medoids++',random_state=0).fit(features) # Kmedoids init='k-medoids++'
    print("Kmedoids")

    print('silhouette_score -------->', silhouette_score(features, clustered.labels_))
    return clustered.labels_

def stl_decomposition(dataset, frequency):
    seasonal = []
    trend = []
    for index in range(len(dataset)):
        if frequency != None:
            stl = STL(dataset[index], frequency, "periodic")

            seasonal.append(stl.seasonal)
            trend.append(stl.trend)
            dataset[index] = dataset[index] - stl.seasonal
        else:
            seasonal.append(np.zeros((dataset[index].shape)))
            trend.append(np.zeros((dataset[index].shape)))

    return dataset, np.array(seasonal), np.array(trend)

def run_local_models(dataset_name, number_of_clusters=2, AEName='LSTM', Dim=8, epochs = 20, batch =20, use_saved_model = False, save_trained_model = False, run=1):
    import gc
    gc.collect()
    print('dataset: ', dataset_name)
    batch_size = batch
    epochs = epochs
    # Prepare & Read Data
    dataset, features, lag, look_forward, sample_overlap, learning_rate, dataset_path, suilin_smape, frequency = get_dataset_params(dataset_name)

    # Normalize Data
    dataset, data_means = normalize_dataset(dataset, look_forward = 0)

    dataset, seasonal, trend = stl_decomposition(dataset, frequency)

    # Normalize Features
    features = normalize_feature_vectors(features)

    # Cluster Series Based On Feature Vectors (Feature Based Clustering)
    if number_of_clusters == 1:
        clusters = np.zeros(len(features))
    else:
        clusters = cluster_series(features, number_of_clusters)

    dataset = np.array(dataset)

    results = {
        'val_SMAPE': np.array([]),
        'val_RMSE': np.array([]),
        'test_SMAPE': np.array([]),
        'test_RMSE': np.array([])
    }

    # Loop Trough Clusters
    for cluster_lable in range(number_of_clusters):
        idx = [x for x in range(len(clusters)) if clusters[x] == cluster_lable]
        cluster_dataset = np.array(dataset)[idx]
        cluster_dataset_means = data_means[idx]
        cluster_dataset_seasonal = seasonal[idx]

        result = run_model_test(cluster_dataset, cluster_dataset_means, cluster_dataset_seasonal, dataset_name, cluster_lable, lag, look_forward, sample_overlap, batch_size, epochs, learning_rate, suilin_smape, dataset_path, use_saved_model, save_trained_model)

        results = {
            'val_SMAPE': np.concatenate((results['val_SMAPE'], result['val_SMAPE'])),
            'val_RMSE': np.concatenate((results['val_RMSE'], result['val_RMSE'])),
            'test_SMAPE': np.concatenate((results['test_SMAPE'], result['test_SMAPE'])),
            'test_RMSE': np.concatenate((results['test_RMSE'], result['test_RMSE'])),
        }
    # print("test smape",results['test_SMAPE'])
    # Print Results Table
    t = Texttable()
    print('\n\n#------------------------------------Scaled------------------------------------#')
    t.add_rows([
        ['Index', 'Mean sMAPE', 'Median sMAPE', 'Mean RMSE', 'Median RMSE'],
        ['Validate', np.mean(results['val_SMAPE']), np.median(results['val_SMAPE']), np.mean(results['val_RMSE']), np.median(results['val_RMSE'])],
        ['Test', np.mean(results['test_SMAPE']), np.median(results['test_SMAPE']), np.mean(results['test_RMSE']), np.median(results['test_RMSE'])]
    ])
    
    print(t.draw())
    t = Texttable()
    t.add_rows([
        ['Run', 'N.Epochs', 'Batch Size', 'Auto Encoder', 'Latent Dimension'],
        [run, epochs,batch_size, AEName, Dim]
    ])
    print(t.draw())
    initial_data = [
    ['Run', 'N.Epochs', 'Batch Size', 'Auto Encoder', 'Latent Dimension', 'Index', 'Mean sMAPE', 'Median sMAPE', 'Mean RMSE', 'Median RMSE'],
    [run, epochs, batch_size, AEName, Dim, 'Validate', np.mean(results['val_SMAPE']), np.median(results['val_SMAPE']), np.mean(results['val_RMSE']), np.median(results['val_RMSE'])],
    [run, epochs, batch_size, AEName, Dim, 'Test', np.mean(results['test_SMAPE']), np.median(results['test_SMAPE']), np.mean(results['test_RMSE']), np.median(results['test_RMSE'])]
    ]# Write the header and initial data to the CSV file

    return results, initial_data

# %%
five_run= {
        'mean_val_SMAPE_5': np.array([]),
        'mean_val_RMSE_5': np.array([]),
        'mean_test_SMAPE_5': np.array([]),
        'mean_test_RMSE_5': np.array([]),
        'median_val_SMAPE_5': np.array([]),
        'median_val_RMSE_5': np.array([]),
        'median_test_SMAPE_5': np.array([]),
        'median_test_RMSE_5': np.array([])
    }


def nn5(AEName="lstm", Dim=32, run=1):
    
    ds_names = [AEName, [5, 15, 25], [20, 40, 60, 80, 100], Dim]
    file_mode = 'w'
    csv_file = "results_"+AEName+"_"+str(Dim)+".csv"
    if os.path.exists(csv_file):
        file_mode = 'a'
    else:
        file_mode = 'w'

    with open(csv_file, mode=file_mode, newline='') as file:
        writer = csv.writer(file)
        for epoch in ds_names[1]:
            for batch in ds_names[2]:
    
                hospital_results, initial_data = run_local_models(dataset_name = 'nn5', number_of_clusters = 2, AEName=ds_names[0], Dim=ds_names[3], epochs = epoch, batch = batch, use_saved_model = False, save_trained_model = False, run=run)
                writer.writerows(initial_data)

# %%
for i in range(5):
    nn5(run=i)

t1 = Texttable()
print('\n\n#------------------------------------Scaled------------------------------------#')
t1.add_rows([
    ['Index', 'Mean sMAPE', 'Median sMAPE', 'Mean RMSE', 'Median RMSE'],
    ['Validate', five_run['mean_val_SMAPE_5'], five_run['mean_val_RMSE_5'], five_run['median_val_SMAPE_5'], five_run['median_val_RMSE_5']],
    ['Test', five_run['mean_test_SMAPE_5'], five_run['mean_test_RMSE_5'], five_run['median_test_SMAPE_5'], five_run['median_test_RMSE_5']]
])
print(t1.draw())
# Out:
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.278     | 19.322       | 4.785     | 4.544       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.047     | 19.032       | 4.800     | 4.528       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 5        | 20         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.789     | 19.768       | 4.859     | 4.640       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.008     | 20.017       | 4.946     | 4.681       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 5        | 40         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.753     | 19.880       | 4.889     | 4.556       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.763     | 19.621       | 4.915     | 4.638       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 5        | 60         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.672     | 19.608       | 4.880     | 4.662       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.340     | 19.069       | 4.819     | 4.533       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 5        | 80         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.288     | 19.411       | 4.804     | 4.510       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.045     | 19.000       | 4.785     | 4.482       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 5        | 100        | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.229     | 19.243       | 4.739     | 4.478       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.336     | 19.330       | 4.818     | 4.539       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 15       | 20         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.560     | 19.725       | 4.841     | 4.597       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.499     | 19.428       | 4.850     | 4.655       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 15       | 40         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 21.152     | 20.144       | 4.926     | 4.682       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.351     | 20.478       | 5.010     | 4.686       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 15       | 60         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.637     | 19.725       | 4.862     | 4.636       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.733     | 19.793       | 4.898     | 4.699       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 15       | 80         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.350     | 19.614       | 4.798     | 4.553       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.224     | 19.146       | 4.813     | 4.567       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 15       | 100        | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.759     | 19.017       | 4.622     | 4.385       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.099     | 19.173       | 4.778     | 4.524       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 25       | 20         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.362     | 19.179       | 4.782     | 4.530       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.714     | 19.637       | 4.909     | 4.606       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 25       | 40         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.314     | 19.437       | 4.779     | 4.539       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.528     | 19.291       | 4.867     | 4.684       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 25       | 60         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.683     | 19.609       | 4.850     | 4.622       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.796     | 19.948       | 4.907     | 4.683       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 25       | 80         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.367     | 19.494       | 4.787     | 4.508       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.548     | 19.416       | 4.856     | 4.619       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 25       | 100        | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 21.328     | 20.492       | 4.994     | 4.678       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.330     | 20.424       | 4.994     | 4.672       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 5        | 20         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.564     | 19.502       | 4.892     | 4.608       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.480     | 19.361       | 4.866     | 4.556       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 5        | 40         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.403     | 19.591       | 4.847     | 4.619       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.140     | 19.133       | 4.796     | 4.611       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 5        | 60         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.628     | 19.655       | 4.875     | 4.684       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.820     | 19.766       | 4.919     | 4.634       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 5        | 80         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.689     | 19.618       | 4.884     | 4.612       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.478     | 19.251       | 4.847     | 4.668       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 5        | 100        | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.781     | 19.703       | 4.861     | 4.603       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.084     | 20.344       | 4.950     | 4.643       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 15       | 20         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.312     | 19.345       | 4.770     | 4.543       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.489     | 19.485       | 4.852     | 4.653       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 15       | 40         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.304     | 19.227       | 4.778     | 4.504       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.292     | 19.154       | 4.826     | 4.617       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 15       | 60         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.350     | 19.443       | 4.799     | 4.563       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.371     | 19.168       | 4.848     | 4.639       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 15       | 80         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.532     | 19.765       | 4.834     | 4.615       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.650     | 19.544       | 4.881     | 4.661       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 15       | 100        | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.947     | 19.357       | 4.665     | 4.385       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.482     | 19.765       | 4.837     | 4.611       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 25       | 20         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.481     | 19.872       | 4.788     | 4.559       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.864     | 19.797       | 4.910     | 4.715       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 25       | 40         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.508     | 19.510       | 4.828     | 4.624       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.853     | 19.657       | 4.918     | 4.682       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 25       | 60         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.499     | 19.607       | 4.814     | 4.553       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.589     | 19.263       | 4.872     | 4.677       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 25       | 80         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.722     | 19.800       | 4.866     | 4.642       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.869     | 19.891       | 4.915     | 4.651       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 25       | 100        | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.476     | 19.610       | 4.815     | 4.568       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.348     | 19.221       | 4.830     | 4.639       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 5        | 20         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.920     | 20.071       | 4.909     | 4.679       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.661     | 19.698       | 4.881     | 4.642       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 5        | 40         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.467     | 19.671       | 4.838     | 4.560       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.280     | 19.291       | 4.830     | 4.601       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 5        | 60         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.694     | 19.710       | 4.880     | 4.624       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.579     | 19.434       | 4.887     | 4.692       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 5        | 80         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.995     | 20.244       | 4.934     | 4.618       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.145     | 20.226       | 4.981     | 4.724       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 5        | 100        | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ...
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 5        | 80         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.511     | 19.434       | 4.839     | 4.661       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.342     | 19.235       | 4.812     | 4.564       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 5        | 100        | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.436     | 19.630       | 4.795     | 4.557       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.684     | 19.612       | 4.868     | 4.626       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 15       | 20         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.642     | 19.811       | 4.835     | 4.615       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.723     | 19.452       | 4.892     | 4.673       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 15       | 40         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.426     | 19.480       | 4.807     | 4.520       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.487     | 19.204       | 4.870     | 4.648       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 15       | 60         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.556     | 19.629       | 4.848     | 4.619       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.601     | 19.674       | 4.876     | 4.657       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 15       | 80         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.981     | 20.179       | 4.902     | 4.644       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.000     | 20.078       | 4.938     | 4.631       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 15       | 100        | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.220     | 19.560       | 4.714     | 4.517       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.510     | 19.467       | 4.836     | 4.580       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 25       | 20         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.283     | 19.234       | 4.764     | 4.592       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.443     | 19.358       | 4.836     | 4.623       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 25       | 40         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.751     | 19.715       | 4.856     | 4.629       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.836     | 19.792       | 4.897     | 4.603       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 25       | 60         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.669     | 20.001       | 4.845     | 4.543       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.945     | 19.815       | 4.937     | 4.659       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 25       | 80         | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.4711017081791807
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (46800, 1, 150)
# valshape (80, 1, 150)
# testshape (80, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (18135, 1, 150)
# valshape (31, 1, 150)
# testshape (31, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.568     | 19.748       | 4.828     | 4.618       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.640     | 19.643       | 4.874     | 4.647       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 25       | 100        | lstm         | 32               |
# +-----+----------+------------+--------------+------------------+
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | []         | []           | []        | []          |
# +----------+------------+--------------+-----------+-------------+
# | Test     | []         | []           | []        | []          |
# +----------+------------+--------------+-----------+-------------+
