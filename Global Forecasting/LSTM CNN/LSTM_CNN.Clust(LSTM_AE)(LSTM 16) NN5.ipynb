# %%
! pip install scikit-learn-extra
# Out:
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.10/site-packages (from scikit-learn-extra) (1.23.5)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn-extra) (1.11.2)
# Requirement already satisfied: scikit-learn>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn-extra) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.1.0)
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0

# %%
! pip install rstl
# Out:
# Collecting rstl
#   Downloading rstl-0.1.3-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rstl) (1.23.5)
# Installing collected packages: rstl
# Successfully installed rstl-0.1.3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids
from sklearn.cluster import SpectralClustering
# %tensorflow_version 1.x
import tensorflow as tf
import keras
import keras.backend as K
from keras import layers
from keras.models import Sequential,Model
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import time
print(tf.__version__)
from keras.layers import MultiHeadAttention
from keras.layers import Dense
import gc
from keras.layers import concatenate
import csv
import math
import warnings
import os

# import xgboost as xgb
warnings.filterwarnings('ignore')
# import GPy, GPyOpt
tfkl = tf.keras.layers
tfk = tf.keras

from rstl import STL
from texttable import Texttable
# Out:
# 2.12.0

# %%
rd='Mahdian/'

def get_dataset_params(dataset_name = 'cif-12'):
    suilin_smape = False
    #-------------------------------------------------- NN5 ------------------------------------------------#
    if dataset_name == 'nn5':
        dataset_path = '/kaggle/working'+'/' + 'NN5'
        raw_data = pd.read_csv('/kaggle/input/dataset-nn5-fixing/nn5.csv',sep='delimeter',header=None)

        features = pd.read_csv("/kaggle/input/ae-nn5-unsupervised-ae/Features_nn5_LSTM_16.csv",sep=',', header=None)


        lag = 150
        look_forward = 56
        batch_size = 1
        epochs = 1
        learning_rate = 0.0001
        suilin_smape = False
        frequency =7

    #------------------------------------------------------------------------------------------------------------#

    sample_overlap = look_forward - 1


    raw_data = raw_data[0].str.split(',', expand=True)

    raw_data = raw_data.to_numpy().astype('float64')
    features = features.to_numpy().astype('float64')
    dataset = []
    for i in range(len(raw_data)):
        dataset.append(raw_data[i][~np.isnan(raw_data[i])])


    return dataset, features, lag, look_forward, sample_overlap, learning_rate, dataset_path, suilin_smape, frequency

# %%
def normalize_dataset(dataset, look_forward ):
    data_means = [];
    for index in range(len(dataset)):
    # Mean Noramlization
        series_mean = np.mean(dataset[index][:len(dataset[index]) - look_forward]) # Train Mean: look_forward || Full Mean: Mean: look_forward = 0

        if series_mean == 0:
            series_mean = 0.001

        data_means.append(series_mean)
        dataset[index] = np.divide(dataset[index], series_mean)

        # Log Transformation
        dataset[index] = np.log(dataset[index] + 1)

    return dataset, np.array(data_means)

def rescale_data_to_main_value(data, means, dataset_seasonal = []):

    for index in range(len(data)):
        if len(dataset_seasonal) != 0:
            data[index] = data[index] + dataset_seasonal[index]
        # Revert Log Transformation
        data[index] = np.e ** data[index]
        data[index] = data[index] - 1

        # Revert Mean Normalization
        data[index] = means[index] * data[index]




    return data

def normalize_feature_vectors(features):
    #------------------- Z-score ----------------------#
#     means = features.mean(0)
#     stds = features.std(0)

#     for i in range(len(features)):
#         features[i] = (features[i] - means) / stds

    #--------------------Min - Max---------------------#
    minimum = features.min(0)
    maximum = features.max(0)

    for i in range(len(features)):
        features[i] = (features[i] - minimum) / (maximum - minimum)


    return features

"""![root_mean_square_deviation.svg](attachment:root_mean_square_deviation.svg)"""

#RMSE
def root_mean_squared_error(actual, forecast, method = 'single_value'):
    # Methods = single_value | per_series
    if method == 'single_value':
        #Flatten To One Vector
        actual = actual.flatten()
        forecast = forecast.flatten()

        return np.sqrt(np.mean(np.square(actual - forecast)))
    elif method == 'per_series':
        rmses = []
        for i in range(len(actual)):
            rmses.append(np.sqrt(np.mean(np.square(actual[i] - forecast[i]))))

        return rmses

"""![YIy33.png](attachment:YIy33.png)"""

#SMAPE
def single_point_smape(actual, forecast, suilin_smape = False):
    if suilin_smape == True:
        epsilon = 0.1

        return (np.sum(2 * np.abs(forecast - actual) / max((np.abs(actual) + np.abs(forecast))+ epsilon, 0.5 + epsilon)))
    else:
        return (np.sum(2 * np.abs(forecast - actual) / (np.abs(actual) + np.abs(forecast))))

def smape(actual, forecast, method = 'single_value', suilin_smape = False):
    # Methods = single_value | per_series
    if method == 'single_value':
        #Flatten To One Vector
        actual = actual.flatten()
        forecast = forecast.flatten()
        sum_smape = 0
        for i in range(len(actual)):
            sum_smape += single_point_smape(actual[i], forecast[i], suilin_smape)
        return 100 * sum_smape / len(actual)

    elif method == 'per_series':
        smapes = []
        for i in range(len(actual)):
            sum_smape = 0
            for j in range(len(actual[i])):
                sum_smape += single_point_smape(actual[i,j], forecast[i,j], suilin_smape)
            smapes.append(100 * sum_smape / len(actual[i]))
        return np.array(smapes)

# Create Samples from DataSet
def create_dataset(sample, look_back, look_forward, sample_overlap, dataset_seasonal):
    if(sample_overlap >= look_forward or sample_overlap < 0): sample_overlap = look_forward - 1
    if(look_forward == 1): sample_overlap = 0

    dataX, dataY, dataY_seasonal = [], [], []
    dataX_means, dataY_means = [], []
    for i in range(0, len(sample) - look_back - look_forward+1, look_forward - sample_overlap):
        dataX.append(sample[i:(i+look_back), 0])
        dataY.append(sample[(i + look_back):(i + look_back + look_forward), 0])

        dataY_seasonal.append(dataset_seasonal[(i + look_back):(i + look_back + look_forward)])


    return np.array(dataX), np.array(dataY), np.array(dataY_seasonal)

# %%
testsize = 20/100
valsize = 20/100

def create_sample(dataX, dataY, data_mean, dataY_seasonal):
    test_size=1
    val_size=1


    train_size=(len(dataX)-test_size)

    trainX, testX = dataX[0:train_size,:], dataX[train_size:,:]
    trainY, testY = dataY[0:train_size,:], dataY[train_size:,:]

    valX, valY = trainX[train_size-val_size:train_size,:],trainY[train_size-val_size:train_size, :]

    trainX = np.reshape(trainX, (trainX.shape[0],1, trainX.shape[1]))
    valX = np.reshape(valX, (valX.shape[0],1, valX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0],1, testX.shape[1]))

    val_means = np.full(len(valY), data_mean)
    test_means = np.full(len(testY), data_mean)

    val_seasonal = dataY_seasonal[train_size-val_size:train_size, :]
    test_seasonal = dataY_seasonal[train_size:,:]

    return np.array(trainX),np.array(valX),np.array(testX),np.array(trainY),np.array(valY),np.array(testY), test_means, val_means, val_seasonal, test_seasonal

# Preprocess Data For Sampling
def all_pre_process(all_dataset, lag, look_forward, sample_overlap, data_means, dataset_seasonal):
    look_back = lag

    trainX = []
    trainY = []

    valX = []
    valY = []

    testX = []
    testY = []

    all_test_means = []
    all_val_means = []

    all_test_seasonals = []
    all_val_seasonals = []

    for index in range(len(all_dataset)):
        sample = np.array(all_dataset[index])
        sample = sample.reshape(sample.shape[0], 1)

        dataX_s, dataY_s, dataY_seasonal = create_dataset(sample, look_back, look_forward, sample_overlap, dataset_seasonal[index])

        temp_trainX, temp_valX, temp_testX, temp_trainY, temp_valY, temp_testY, test_means, val_means, val_seasonal, test_seasonal = create_sample(dataX_s,dataY_s,data_means[index], dataY_seasonal)

        trainX = trainX + temp_trainX.tolist()
        trainY = trainY + temp_trainY.tolist()

        valX = valX + temp_valX.tolist()
        valY = valY + temp_valY.tolist()

        testX = testX + temp_testX.tolist()
        testY = testY + temp_testY.tolist()

        all_test_means = all_test_means + test_means.tolist()
        all_val_means = all_val_means + val_means.tolist()

        all_test_seasonals = all_test_seasonals + test_seasonal.tolist()
        all_val_seasonals = all_val_seasonals + val_seasonal.tolist()


    return np.array(trainX), np.array(valX), np.array(testX), np.array(trainY), np.array(valY), np.array(testY), np.array(all_test_means), np.array(all_val_means), np.array(all_val_seasonals), np.array(all_test_seasonals)

def save_prediction_result(data, dataset_name = 'cif-6', dataset_path = ''):
    if dataset_name == '':
        filename = dataset_name + '-results.csv'
    else:
        filename = dataset_path + '/' + dataset_name + '-results.csv'


    df = pd.DataFrame(data)
    df.to_csv(filename, sep=',',index=False,header=False)

# %%
# Main Work & Functionality
def run_model_test(dataset, data_means, dataset_seasonal, dataset_name, cluster_lable, lag, look_forward, sample_overlap, batch_size, epochs, learning_rate, suilin_smape, dataset_path, use_saved_model = False, save_trained_model = False):

    # Initialize Look Forward & Back
    look_back=lag
    calculations_method = 'per_series' # single_value | per_series

    trainX, valX, testX, trainY, valY, testY, test_means, val_means, val_seasonal, test_seasonal = all_pre_process(dataset, lag, look_forward, sample_overlap, data_means, dataset_seasonal)

    # Get Model From Local Saved File
    if use_saved_model == True:
        if os.path.exists(dataset_path + '/' + dataset_name + '-model-cluster-' + str(cluster_lable)) == True:
            model = keras.models.load_model(dataset_path + '/' + dataset_name  + '-model-cluster-' + str(cluster_lable))

            val_prediction_results = model.predict([valX],batch_size=16, verbose=0)

            val_RMSE = root_mean_squared_error(valY, val_prediction_results, calculations_method)
            val_SMAPE = smape(valY, val_prediction_results, calculations_method, suilin_smape)

            ######################################################
            test_prediction_results = model.predict([testX],batch_size=16, verbose=0)

            test_RMSE = root_mean_squared_error(testY, test_prediction_results, calculations_method)
            test_SMAPE = smape(testY, test_prediction_results, calculations_method, suilin_smape)

        else:
            use_saved_model = False
            save_trained_model = True

    # Train Model From Scratch
    if use_saved_model == False:

        dense_neuron = 100
        denselayer_activation = 'linear' #None
        output_activation = 'linear' #'linear'

        print("---------------------------------------------------------------------")
        print("lag", lag)
        print("look_forward", look_forward)
        print("sample overlap", sample_overlap)
        print("trainshape", trainX.shape)
        print("valshape", valX.shape)
        print("testshape", testX.shape)
        print(learning_rate, dense_neuron, denselayer_activation, output_activation)



        validation_loss=[]
        test_loss=[]
        iter = 1
        for j in range(iter):
### Network Structure
            # #---------------------------------------Input Layer------------------------------------------#
            input_layer = layers.Input(shape = (1, lag,), name = "Input-Layer")



            lstm1=keras.layers.LSTM(128,activation='linear',return_sequences=True)(input_layer)
            lstm2=keras.layers.LSTM(64,activation='linear',return_sequences=True)(lstm1)
            conv = keras.layers.Conv1D(64,
                                          strides=2,
                                          kernel_size=4,
                                          activation=None,
                                          padding="same",)(lstm2)

            # flatten_layer1 = keras.layers.Flatten(name="Flatten-Layer")(multi_head_attention_layer)

            flatten_layer2=keras.layers.Flatten(name="Flatten-Layer2")(conv)
            # concat=keras.layers.concatenate([flatten_layer1,flatten_layer2])

            dense_layer1 = Dense(
                dense_neuron,
                activation = denselayer_activation,
                name = "Fully-Connected-Layer")(flatten_layer2)

            dense_layer2 = Dense(
                look_forward,
                activation = None,
                name = "Output-Layer")(dense_layer1)


            # Create Model
            model = Model(inputs = [input_layer], outputs = dense_layer2)

            # Optimizer
            opt=tf.keras.optimizers.Adam(learning_rate=learning_rate)

            # Compile Model
            model.compile(loss="mse",optimizer=opt,metrics=["mse"])

            for k in range(epochs):
                history = model.fit([trainX], trainY, validation_data=([valX, valY]),
                    verbose = 0,
                    batch_size = batch_size,
        #             callbacks = [
        #                 tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
        #                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=20, factor=0.5, min_lr=1e-5)
        #             ]
            ).history

                val_prediction_results = model.predict([valX],batch_size=16, verbose=0)

                val_RMSE = root_mean_squared_error(valY, val_prediction_results, calculations_method)
                val_SMAPE = smape(valY, val_prediction_results, calculations_method, suilin_smape)

                ######################################################
                test_prediction_results = model.predict([testX],batch_size=16, verbose=0)

                test_RMSE = root_mean_squared_error(testY, test_prediction_results, calculations_method)
                test_SMAPE = smape(testY, test_prediction_results, calculations_method, suilin_smape)

                validation_loss.append(np.mean(val_RMSE))
                test_loss.append(np.mean(test_RMSE))

            K.clear_session()
            gc.collect()

            # Save model to a file if wanted
            if save_trained_model == True:
                model.save(dataset_path + '/' + dataset_name + '-model-cluster-' + str(cluster_lable))

            model=None
            del history

    #############################################
    rescaled_valY = rescale_data_to_main_value(valY, val_means, val_seasonal)
    rescaled_val_prediction_results = rescale_data_to_main_value(val_prediction_results, val_means)
    val_SMAPE = smape(rescaled_valY, rescaled_val_prediction_results, calculations_method, suilin_smape)
    val_RMSE = root_mean_squared_error(rescaled_valY, rescaled_val_prediction_results, calculations_method)


    rescaled_testY = rescale_data_to_main_value(testY, test_means, test_seasonal)
    rescaled_test_prediction_results = rescale_data_to_main_value(test_prediction_results, test_means, test_seasonal)
    test_SMAPE = smape(rescaled_testY, rescaled_test_prediction_results, calculations_method)
    test_RMSE = root_mean_squared_error(rescaled_testY, rescaled_test_prediction_results, calculations_method)

    results = {
            'val_SMAPE': val_SMAPE,
            'val_RMSE': val_RMSE,
            'test_SMAPE': test_SMAPE,
            'test_RMSE': test_RMSE
        }
    #############################################

    return results

# %%
from sklearn.metrics import silhouette_score

def cluster_series(features, number_of_clusters=2):
    clustered = KMedoids(n_clusters=number_of_clusters, init='k-medoids++',random_state=0).fit(features) # Kmedoids init='k-medoids++'
    print("Kmedoids")

    print('silhouette_score -------->', silhouette_score(features, clustered.labels_))
    return clustered.labels_

def stl_decomposition(dataset, frequency):
    seasonal = []
    trend = []
    for index in range(len(dataset)):
        if frequency != None:
            stl = STL(dataset[index], frequency, "periodic")

            seasonal.append(stl.seasonal)
            trend.append(stl.trend)
            dataset[index] = dataset[index] - stl.seasonal
        else:
            seasonal.append(np.zeros((dataset[index].shape)))
            trend.append(np.zeros((dataset[index].shape)))

    return dataset, np.array(seasonal), np.array(trend)

def run_local_models(dataset_name, number_of_clusters=2, AEName='LSTM', Dim=8, epochs = 20, batch =20, use_saved_model = False, save_trained_model = False, run=1):
    import gc
    gc.collect()
    print('dataset: ', dataset_name)
    batch_size = batch
    epochs = epochs
    # Prepare & Read Data
    dataset, features, lag, look_forward, sample_overlap, learning_rate, dataset_path, suilin_smape, frequency = get_dataset_params(dataset_name)

    # Normalize Data
    dataset, data_means = normalize_dataset(dataset, look_forward = 0)

    dataset, seasonal, trend = stl_decomposition(dataset, frequency)

    # Normalize Features
    features = normalize_feature_vectors(features)

    # Cluster Series Based On Feature Vectors (Feature Based Clustering)
    if number_of_clusters == 1:
        clusters = np.zeros(len(features))
    else:
        clusters = cluster_series(features, number_of_clusters)

    dataset = np.array(dataset)

    results = {
        'val_SMAPE': np.array([]),
        'val_RMSE': np.array([]),
        'test_SMAPE': np.array([]),
        'test_RMSE': np.array([])
    }

    # Loop Trough Clusters
    for cluster_lable in range(number_of_clusters):
        idx = [x for x in range(len(clusters)) if clusters[x] == cluster_lable]
        cluster_dataset = np.array(dataset)[idx]
        cluster_dataset_means = data_means[idx]
        cluster_dataset_seasonal = seasonal[idx]

        result = run_model_test(cluster_dataset, cluster_dataset_means, cluster_dataset_seasonal, dataset_name, cluster_lable, lag, look_forward, sample_overlap, batch_size, epochs, learning_rate, suilin_smape, dataset_path, use_saved_model, save_trained_model)

        results = {
            'val_SMAPE': np.concatenate((results['val_SMAPE'], result['val_SMAPE'])),
            'val_RMSE': np.concatenate((results['val_RMSE'], result['val_RMSE'])),
            'test_SMAPE': np.concatenate((results['test_SMAPE'], result['test_SMAPE'])),
            'test_RMSE': np.concatenate((results['test_RMSE'], result['test_RMSE'])),
        }
    # print("test smape",results['test_SMAPE'])
    # Print Results Table
    t = Texttable()
    print('\n\n#------------------------------------Scaled------------------------------------#')
    t.add_rows([
        ['Index', 'Mean sMAPE', 'Median sMAPE', 'Mean RMSE', 'Median RMSE'],
        ['Validate', np.mean(results['val_SMAPE']), np.median(results['val_SMAPE']), np.mean(results['val_RMSE']), np.median(results['val_RMSE'])],
        ['Test', np.mean(results['test_SMAPE']), np.median(results['test_SMAPE']), np.mean(results['test_RMSE']), np.median(results['test_RMSE'])]
    ])
    
    print(t.draw())
    t = Texttable()
    t.add_rows([
        ['Run', 'N.Epochs', 'Batch Size', 'Auto Encoder', 'Latent Dimension'],
        [run, epochs,batch_size, AEName, Dim]
    ])
    print(t.draw())
    initial_data = [
    ['Run', 'N.Epochs', 'Batch Size', 'Auto Encoder', 'Latent Dimension', 'Index', 'Mean sMAPE', 'Median sMAPE', 'Mean RMSE', 'Median RMSE'],
    [run, epochs, batch_size, AEName, Dim, 'Validate', np.mean(results['val_SMAPE']), np.median(results['val_SMAPE']), np.mean(results['val_RMSE']), np.median(results['val_RMSE'])],
    [run, epochs, batch_size, AEName, Dim, 'Test', np.mean(results['test_SMAPE']), np.median(results['test_SMAPE']), np.mean(results['test_RMSE']), np.median(results['test_RMSE'])]
    ]# Write the header and initial data to the CSV file

    return results, initial_data

# %%
five_run= {
        'mean_val_SMAPE_5': np.array([]),
        'mean_val_RMSE_5': np.array([]),
        'mean_test_SMAPE_5': np.array([]),
        'mean_test_RMSE_5': np.array([]),
        'median_val_SMAPE_5': np.array([]),
        'median_val_RMSE_5': np.array([]),
        'median_test_SMAPE_5': np.array([]),
        'median_test_RMSE_5': np.array([])
    }


def nn5(AEName="lstm", Dim=16, run=1):
    
    ds_names = [AEName, [35, 50], [20, 40, 60, 80, 100], Dim]
    file_mode = 'w'
    csv_file = "results_"+AEName+"_"+str(Dim)+".csv"
    if os.path.exists(csv_file):
        file_mode = 'a'
    else:
        file_mode = 'w'

    with open(csv_file, mode=file_mode, newline='') as file:
        writer = csv.writer(file)
        for epoch in ds_names[1]:
            for batch in ds_names[2]:
    
                hospital_results, initial_data = run_local_models(dataset_name = 'nn5', number_of_clusters = 2, AEName=ds_names[0], Dim=ds_names[3], epochs = epoch, batch = batch, use_saved_model = False, save_trained_model = False, run=run)
                writer.writerows(initial_data)

# %%
for i in range(5):
    nn5(run=i)

t1 = Texttable()
print('\n\n#------------------------------------Scaled------------------------------------#')
t1.add_rows([
    ['Index', 'Mean sMAPE', 'Median sMAPE', 'Mean RMSE', 'Median RMSE'],
    ['Validate', five_run['mean_val_SMAPE_5'], five_run['mean_val_RMSE_5'], five_run['median_val_SMAPE_5'], five_run['median_val_RMSE_5']],
    ['Test', five_run['mean_test_SMAPE_5'], five_run['mean_test_RMSE_5'], five_run['median_test_SMAPE_5'], five_run['median_test_RMSE_5']]
])
print(t1.draw())
# Out:
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.062     | 19.180       | 4.654     | 4.314       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.611     | 19.734       | 4.859     | 4.537       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 35       | 20         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.657     | 19.842       | 4.811     | 4.490       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.125     | 20.119       | 4.959     | 4.623       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 35       | 40         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.421     | 19.273       | 4.784     | 4.434       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.682     | 19.749       | 4.875     | 4.557       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 35       | 60         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.841     | 19.628       | 4.876     | 4.537       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.466     | 20.280       | 5.005     | 4.590       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 35       | 80         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.451     | 19.201       | 4.802     | 4.532       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.793     | 19.470       | 4.894     | 4.587       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 35       | 100        | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.673     | 18.870       | 4.605     | 4.243       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.274     | 19.513       | 4.788     | 4.473       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 50       | 20         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.141     | 19.540       | 4.719     | 4.404       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.773     | 19.917       | 4.883     | 4.570       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 50       | 40         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.960     | 18.968       | 4.654     | 4.390       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.399     | 19.072       | 4.823     | 4.497       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 50       | 60         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.915     | 18.834       | 4.702     | 4.392       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.675     | 19.765       | 4.907     | 4.584       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 50       | 80         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.446     | 19.573       | 4.764     | 4.390       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.995     | 20.050       | 4.917     | 4.576       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 0   | 50       | 100        | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.111     | 19.342       | 4.685     | 4.378       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.882     | 19.983       | 4.890     | 4.538       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 35       | 20         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.466     | 19.352       | 4.754     | 4.480       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.889     | 19.825       | 4.907     | 4.586       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 35       | 40         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.264     | 19.339       | 4.725     | 4.331       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.902     | 19.893       | 4.934     | 4.554       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 35       | 60         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.888     | 19.900       | 4.870     | 4.546       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.356     | 20.567       | 5.016     | 4.639       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 35       | 80         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.743     | 19.815       | 4.875     | 4.469       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.114     | 20.300       | 4.957     | 4.560       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 35       | 100        | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.132     | 18.335       | 4.505     | 4.242       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 19.905     | 19.152       | 4.737     | 4.430       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 50       | 20         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.991     | 19.134       | 4.674     | 4.339       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.584     | 19.719       | 4.863     | 4.554       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 50       | 40         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.319     | 19.398       | 4.729     | 4.388       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.839     | 19.906       | 4.905     | 4.631       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 50       | 60         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.464     | 19.588       | 4.794     | 4.448       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.024     | 20.203       | 4.939     | 4.590       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 50       | 80         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.537     | 19.281       | 4.819     | 4.532       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.067     | 20.118       | 4.950     | 4.572       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 1   | 50       | 100        | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.566     | 18.753       | 4.598     | 4.249       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.237     | 19.306       | 4.802     | 4.482       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 35       | 20         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.595     | 19.581       | 4.800     | 4.453       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.027     | 19.856       | 4.943     | 4.619       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 35       | 40         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.392     | 19.506       | 4.786     | 4.411       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.015     | 20.254       | 4.933     | 4.564       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 35       | 60         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.751     | 19.693       | 4.846     | 4.463       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.986     | 19.979       | 4.927     | 4.535       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 35       | 80         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.271     | 19.004       | 4.753     | 4.475       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.860     | 19.723       | 4.916     | 4.572       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 35       | 100        | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.361     | 18.473       | 4.560     | 4.146       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.058     | 19.145       | 4.761     | 4.434       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 50       | 20         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.642     | 18.850       | 4.620     | 4.317       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.439     | 19.839       | 4.852     | 4.528       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 50       | 40         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.334     | 19.313       | 4.745     | 4.416       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.814     | 19.593       | 4.915     | 4.632       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 50       | 60         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.364     | 19.290       | 4.748     | 4.420       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.849     | 19.624       | 4.921     | 4.605       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 50       | 80         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.326     | 19.107       | 4.772     | 4.461       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.955     | 20.152       | 4.919     | 4.628       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 2   | 50       | 100        | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.484     | 18.741       | 4.536     | 4.204       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 19.983     | 18.678       | 4.746     | 4.448       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 3   | 35       | 20         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.659     | 19.356       | 4.793     | 4.462       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.286     | 20.230       | 4.989     | 4.616       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 3   | 35       | 40         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.460     | 19.267       | 4.788     | 4.454       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.036     | 20.225       | 4.942     | 4.542       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 3   | 35       | 60         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 21.107     | 20.459       | 4.900     | 4.509       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.515     | 20.698       | 5.034     | 4.691       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 3   | 35       | 80         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.932     | 19.999       | 4.908     | 4.522       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.409     | 20.670       | 5.045     | 4.656       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 3   | 35       | 100        | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# ...
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 3   | 50       | 80         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.972     | 18.823       | 4.689     | 4.394       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.482     | 19.246       | 4.846     | 4.587       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 3   | 50       | 100        | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.863     | 19.323       | 4.631     | 4.318       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.006     | 19.105       | 4.777     | 4.497       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 35       | 20         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.947     | 18.965       | 4.682     | 4.402       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.288     | 19.213       | 4.813     | 4.476       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 35       | 40         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.714     | 19.563       | 4.849     | 4.525       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.127     | 20.170       | 4.969     | 4.628       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 35       | 60         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.577     | 19.225       | 4.780     | 4.429       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.877     | 19.590       | 4.916     | 4.630       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 35       | 80         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.890     | 19.943       | 4.876     | 4.545       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.464     | 20.617       | 5.016     | 4.615       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 35       | 100        | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 19.467     | 18.471       | 4.566     | 4.162       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.200     | 18.804       | 4.785     | 4.459       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 50       | 20         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.115     | 19.173       | 4.685     | 4.413       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.413     | 19.407       | 4.830     | 4.544       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 50       | 40         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.445     | 19.583       | 4.766     | 4.463       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.990     | 20.106       | 4.942     | 4.573       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 50       | 60         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.395     | 19.510       | 4.769     | 4.435       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 20.885     | 19.950       | 4.930     | 4.613       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 50       | 80         | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
# dataset:  nn5
# Kmedoids
# silhouette_score --------> 0.48267828568753735
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (50310, 1, 150)
# valshape (86, 1, 150)
# testshape (86, 1, 150)
# 0.0001 100 linear linear
# ---------------------------------------------------------------------
# lag 150
# look_forward 56
# sample overlap 55
# trainshape (14625, 1, 150)
# valshape (25, 1, 150)
# testshape (25, 1, 150)
# 0.0001 100 linear linear
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | 20.828     | 19.869       | 4.862     | 4.514       |
# +----------+------------+--------------+-----------+-------------+
# | Test     | 21.303     | 20.505       | 5.004     | 4.670       |
# +----------+------------+--------------+-----------+-------------+
# +-----+----------+------------+--------------+------------------+
# | Run | N.Epochs | Batch Size | Auto Encoder | Latent Dimension |
# +=====+==========+============+==============+==================+
# | 4   | 50       | 100        | lstm         | 16               |
# +-----+----------+------------+--------------+------------------+
#
#
# #------------------------------------Scaled------------------------------------#
# +----------+------------+--------------+-----------+-------------+
# |  Index   | Mean sMAPE | Median sMAPE | Mean RMSE | Median RMSE |
# +==========+============+==============+===========+=============+
# | Validate | []         | []           | []        | []          |
# +----------+------------+--------------+-----------+-------------+
# | Test     | []         | []           | []        | []          |
# +----------+------------+--------------+-----------+-------------+
